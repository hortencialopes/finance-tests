# %%
print("Jupyter")
import sys
# !{sys.executable} -m pip install yfinance
# Out:
# Jupyter
# ...
#      |████████████████████████████████| 6.3 MB 5.0 MB/s eta 0:00:01
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.60-py2.py3-none-any.whl size=23810 sha256=ce159b97fc6d1989c5143905d6b104b8427123020888c7a99850c7ba0ac62331
#   Stored in directory: /home/jovyan/.cache/pip/wheels/00/82/08/6533d73a6ab802736648e94200976582cc6efd5854b1db6565
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=65f73ea382eda418683079b872252692f17fe4101c280dbfc5a5fe4ff5762439
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5e/8a/c4/59c699498647c7c94b14c87a904ca7540646107b3d94b7c320
# Successfully built yfinance multitasking
# ...

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 163000,
# ...
